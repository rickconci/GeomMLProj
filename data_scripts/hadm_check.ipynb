# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import torch

# %%
hadm_id = 23086112


TS_path = '/Users/riccardoconci/Local_documents/!!GeomML_2025/GeomMLProj/temp_dfs/sorted_filtered_df.pkl'
TS_df = pickle.load(open(TS_path, 'rb'))

base_df_path = '/Users/riccardoconci/Local_documents/!!GeomML_2025/GeomMLProj/temp_dfs/merged_with_disch_df_final_filtered.pkl'
base_df = pickle.load(open(base_df_path, 'rb'))

# %%
TS_df[TS_df['hadm_id'] == hadm_id]
# Out:
#              hadm_id           charttime  itemid     value           name  \
# 14961533  23086112.0 2159-12-14 10:40:00   51146 -0.005682      Basophils
# 14961534  23086112.0 2159-12-14 10:40:00   51200 -0.005957    Eosinophils
# 14961535  23086112.0 2159-12-14 10:40:00   51221 -0.003801     Hematocrit
# 14961536  23086112.0 2159-12-14 10:40:00   51222 -0.004663     Hemoglobin
# 14961537  23086112.0 2159-12-14 10:40:00   51244 -0.008168    Lymphocytes
# ...              ...                 ...     ...       ...            ...
# 14961635  23086112.0 2159-12-17 07:34:00   50947 -0.493850              I
# 14961636  23086112.0 2159-12-17 07:34:00   50971 -0.002755      Potassium
# 14961637  23086112.0 2159-12-17 07:34:00   50983 -0.000818         Sodium
# 14961638  23086112.0 2159-12-17 07:34:00   51006 -0.007649  Urea Nitrogen
# 14961639  23086112.0 2159-12-17 07:34:00   51678 -0.237439              L
#
#             category
# 14961533  Hematology
# 14961534  Hematology
# 14961535  Hematology
# 14961536  Hematology
# 14961537  Hematology
# ...              ...
# 14961635   Chemistry
# 14961636   Chemistry
# 14961637   Chemistry
# 14961638   Chemistry
# 14961639   Chemistry
#
# [107 rows x 6 columns]

# %%
base_df[base_df['hadm_id'] == hadm_id]
# Out:
#          subject_id   hadm_id           admittime           dischtime  \
# 1881465    19387552  23086112 2159-12-15 14:19:00 2159-12-20 21:20:00
# 1881466    19387552  23086112 2159-12-15 14:19:00 2159-12-20 21:20:00
# 1881467    19387552  23086112 2159-12-15 14:19:00 2159-12-20 21:20:00
# 1881468    19387552  23086112 2159-12-15 14:19:00 2159-12-20 21:20:00
# 1881469    19387552  23086112 2159-12-15 14:19:00 2159-12-20 21:20:00
# 1881470    19387552  23086112 2159-12-15 14:19:00 2159-12-20 21:20:00
#
#         deathtime     admission_type admit_provider_id  admission_location  \
# 1881465       NaT  OBSERVATION ADMIT            P89JSB  PHYSICIAN REFERRAL
# 1881466       NaT  OBSERVATION ADMIT            P89JSB  PHYSICIAN REFERRAL
# 1881467       NaT  OBSERVATION ADMIT            P89JSB  PHYSICIAN REFERRAL
# 1881468       NaT  OBSERVATION ADMIT            P89JSB  PHYSICIAN REFERRAL
# 1881469       NaT  OBSERVATION ADMIT            P89JSB  PHYSICIAN REFERRAL
# 1881470       NaT  OBSERVATION ADMIT            P89JSB  PHYSICIAN REFERRAL
#
#         discharge_location insurance  ... transfer_id  eventtype  \
# 1881465              REHAB   Private  ...  30374282.0  discharge
# 1881466              REHAB   Private  ...  34835219.0   transfer
# 1881467              REHAB   Private  ...  35304612.0   transfer
# 1881468              REHAB   Private  ...  35322941.0         ED
# 1881469              REHAB   Private  ...  37774990.0   transfer
# 1881470              REHAB   Private  ...  39957451.0      admit
#
#                      careunit               intime              outtime  \
# 1881465               UNKNOWN  2159-12-20 21:40:41                  NaN
# 1881466              Medicine  2159-12-16 17:49:45  2159-12-20 21:40:41
# 1881467              Medicine  2159-12-16 17:03:07  2159-12-16 17:17:19
# 1881468  Emergency Department  2159-12-14 10:13:00  2159-12-15 18:14:00
# 1881469              Medicine  2159-12-16 17:17:19  2159-12-16 17:49:45
# 1881470              Medicine  2159-12-15 18:14:00  2159-12-16 17:03:07
#
#          admit_duration death_timestamp  days_disch_to_death  \
# 1881465        5.292361      2162-11-06          1051.111111
# 1881466        5.292361      2162-11-06          1051.111111
# 1881467        5.292361      2162-11-06          1051.111111
# 1881468        5.292361      2162-11-06          1051.111111
# 1881469        5.292361      2162-11-06          1051.111111
# 1881470        5.292361      2162-11-06          1051.111111
#
#          hours_admission_to_death days_admission_to_death
# 1881465              25353.683333             1056.403472
# 1881466              25353.683333             1056.403472
# 1881467              25353.683333             1056.403472
# 1881468              25353.683333             1056.403472
# 1881469              25353.683333             1056.403472
# 1881470              25353.683333             1056.403472
#
# [6 rows x 32 columns]

# %%
temp_dfs_path = '/Users/riccardoconci/Local_documents/!!GeomML_2025/GeomMLProj/temp_dfs'
tensor_key = f'tensor_cache_{hadm_id}.pt'
tensor_path = os.path.join(temp_dfs_path, tensor_key)
tensor_data = torch.load(tensor_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 4
#       2 tensor_key = f'tensor_cache_{hadm_id}.pt'
#       3 tensor_path = os.path.join(temp_dfs_path, tensor_key)
# ----> 4 tensor_data = torch.load(tensor_path)
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/serialization.py:1425, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1422 if "encoding" not in pickle_load_args.keys():
#    1423     pickle_load_args["encoding"] = "utf-8"
# -> 1425 with _open_file_like(f, "rb") as opened_file:
#    1426     if _is_zipfile(opened_file):
#    1427         # The zipfile reader is going to advance the current file position.
#    1428         # If we want to actually tail call to torch.jit.load, we need to
#    1429         # reset back to the original position.
#    1430         orig_position = opened_file.tell()
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/serialization.py:751, in _open_file_like(name_or_buffer, mode)
#     749 def _open_file_like(name_or_buffer, mode):
#     750     if _is_path(name_or_buffer):
# --> 751         return _open_file(name_or_buffer, mode)
#     752     else:
#     753         if "w" in mode:
#
# File ~/miniforge3/lib/python3.12/site-packages/torch/serialization.py:732, in _open_file.__init__(self, name, mode)
#     731 def __init__(self, name, mode):
# --> 732     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/riccardoconci/Local_documents/!!GeomML_2025/GeomMLProj/temp_dfs/tensor_cache_23086112.pt'

# %%
hadm_lengths_path = '/Users/riccardoconci/Local_documents/!!GeomML_2025/GeomMLProj/temp_dfs/hadm_lengths.pkl'
hadm_lengths = pickle.load(open(hadm_lengths_path, 'rb'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 4
#       1 hadm_lengths_path = '/Users/riccardoconci/Local_documents/!!GeomML_2025/GeomMLProj/temp_dfs/hadm_lengths.pkl'
#       2 hadm_lengths = pickle.load(open(hadm_lengths_path, 'rb'))
# ----> 4 hadm_lengths[hadm_lengths['hadm_id'] == hadm_id]
#
# KeyError: 'hadm_id'

# %%
hadm_lengths
# Out:
# {20000019.0: 4,
#  20000041.0: 5,
#  20000057.0: 3,
#  20000102.0: 1,
#  20000147.0: 13,
#  20000347.0: 2,
#  20000343.0: 6,
#  20000239.0: 3,
#  20000351.0: 11,
#  20000471.0: 4,
#  20000502.0: 2,
#  20000629.0: 15,
#  20000694.0: 5,
#  20000750.0: 1,
#  20000769.0: 11,
#  20001002.0: 4,
#  20001259.0: 10,
#  20001068.0: 4,
#  20001494.0: 18,
#  20001305.0: 22,
#  20001395.0: 19,
#  20001504.0: 2,
#  20001561.0: 8,
#  20001720.0: 3,
#  20001789.0: 4,
#  20001825.0: 4,
#  20001811.0: 45,
#  20001831.0: 7,
#  20001984.0: 9,
#  20001956.0: 4,
#  20002027.0: 3,
#  20002081.0: 5,
#  20002195.0: 3,
#  20002252.0: 9,
#  20002287.0: 2,
#  20002270.0: 8,
#  20002356.0: 15,
#  20002267.0: 29,
#  20002454.0: 9,
#  20002638.0: 6,
#  20002636.0: 32,
#  20002506.0: 52,
#  20002810.0: 21,
#  20002950.0: 9,
#  20003008.0: 13,
#  20003011.0: 12,
#  20003040.0: 4,
#  20003070.0: 5,
#  20003332.0: 5,
#  20003239.0: 3,
#  20003563.0: 6,
#  20003425.0: 37,
#  20003543.0: 34,
#  20003587.0: 8,
#  20003733.0: 5,
#  20003804.0: 3,
#  20003739.0: 17,
#  20003880.0: 21,
#  20003946.0: 2,
#  20004004.0: 16,
#  20004038.0: 4,
#  20004165.0: 11,
#  20004387.0: 4,
#  20004357.0: 36,
#  20004456.0: 6,
#  20004490.0: 3,
#  20004408.0: 7,
#  20004541.0: 14,
#  20004577.0: 9,
#  20004775.0: 17,
#  20004829.0: 4,
#  20004568.0: 7,
#  20005079.0: 4,
#  20004866.0: 2,
#  20005241.0: 23,
#  20005077.0: 2,
#  20005361.0: 7,
#  20005374.0: 11,
#  20005426.0: 10,
#  20005479.0: 22,
#  20005513.0: 2,
#  20005609.0: 5,
#  20005525.0: 6,
#  20005666.0: 2,
#  20005705.0: 9,
#  20005721.0: 6,
#  20005776.0: 10,
#  20005809.0: 10,
#  20005859.0: 3,
#  20005914.0: 7,
#  20006038.0: 5,
#  20006087.0: 2,
#  20006309.0: 40,
#  20006108.0: 4,
#  20006303.0: 6,
#  20006377.0: 15,
#  20006521.0: 6,
#  20006517.0: 3,
#  20006447.0: 2,
#  20006409.0: 61,
#  20006679.0: 3,
#  20006771.0: 15,
#  20006730.0: 6,
#  20006808.0: 6,
#  20006756.0: 4,
#  20006820.0: 5,
#  20006842.0: 3,
#  20006862.0: 12,
#  20006983.0: 7,
#  20006989.0: 5,
#  20007037.0: 12,
#  20007022.0: 12,
#  20007086.0: 3,
#  20007156.0: 4,
#  20007226.0: 13,
#  20007291.0: 5,
#  20007246.0: 6,
#  20007388.0: 3,
#  20007516.0: 7,
#  20007526.0: 7,
#  20007567.0: 13,
#  20007517.0: 6,
#  20007609.0: 3,
#  20007876.0: 2,
#  20007599.0: 1,
#  20007831.0: 14,
#  20007905.0: 23,
#  20007937.0: 4,
#  20007908.0: 2,
#  20007881.0: 6,
#  20007983.0: 6,
#  20007997.0: 16,
#  20008052.0: 1,
#  20008098.0: 30,
#  20008145.0: 1,
#  20008236.0: 7,
#  20008306.0: 15,
#  20008372.0: 5,
#  20008400.0: 28,
#  20008569.0: 6,
#  20008476.0: 14,
#  20008586.0: 16,
#  20008546.0: 6,
#  20008598.0: 1,
#  20008724.0: 13,
#  20008692.0: 14,
#  20008821.0: 4,
#  20008807.0: 50,
#  20008851.0: 20,
#  20008887.0: 3,
#  20009061.0: 3,
#  20009053.0: 17,
#  20008984.0: 9,
#  20009173.0: 7,
#  20009241.0: 16,
#  20009197.0: 14,
#  20009260.0: 2,
#  20009330.0: 51,
#  20009415.0: 6,
#  20009335.0: 24,
#  20009480.0: 5,
#  20009446.0: 24,
#  20009511.0: 4,
#  20009546.0: 2,
#  20009581.0: 3,
#  20009550.0: 24,
#  20009652.0: 2,
#  20009759.0: 17,
#  20009763.0: 3,
#  20009795.0: 7,
#  20009881.0: 1,
#  20009896.0: 5,
#  20010003.0: 13,
#  20010021.0: 10,
#  20010031.0: 6,
#  20010073.0: 5,
#  20010079.0: 7,
#  20010074.0: 40,
#  20010211.0: 9,
#  20010116.0: 19,
#  20010295.0: 3,
#  20010297.0: 5,
#  20010341.0: 6,
#  20010282.0: 34,
#  20010443.0: 4,
#  20010682.0: 6,
#  20010703.0: 14,
#  20010709.0: 3,
#  20010748.0: 4,
#  20010741.0: 24,
#  20010879.0: 18,
#  20010729.0: 1,
#  20010894.0: 2,
#  20010951.0: 2,
#  20010924.0: 6,
#  20010895.0: 3,
#  20011101.0: 4,
#  20011117.0: 15,
#  20011281.0: 18,
#  20011234.0: 5,
#  20011320.0: 2,
#  20011517.0: 2,
#  20011635.0: 4,
#  20011640.0: 11,
#  20011665.0: 2,
#  20011631.0: 14,
#  20011674.0: 6,
#  20011679.0: 10,
#  20011839.0: 4,
#  20012034.0: 13,
#  20012147.0: 3,
#  20012094.0: 55,
#  20012238.0: 9,
#  20012381.0: 5,
#  20012316.0: 44,
#  20012332.0: 4,
#  20012390.0: 1,
#  20012460.0: 4,
#  20012543.0: 2,
#  20012508.0: 3,
#  20012627.0: 1,
#  20012649.0: 2,
#  20012618.0: 3,
#  20012654.0: 13,
#  20012726.0: 1,
#  20012830.0: 8,
#  20012747.0: 9,
#  20012846.0: 7,
#  20012854.0: 7,
#  20013000.0: 5,
#  20012858.0: 22,
#  20013016.0: 7,
#  20012936.0: 3,
#  20013098.0: 1,
#  20013061.0: 9,
#  20013232.0: 5,
#  20013120.0: 7,
#  20013280.0: 11,
#  20013299.0: 1,
#  20013314.0: 3,
#  20013317.0: 2,
#  20013562.0: 5,
#  20013426.0: 4,
#  20013519.0: 4,
#  20013602.0: 9,
#  20013597.0: 4,
#  20013662.0: 11,
#  20013674.0: 6,
#  20013743.0: 2,
#  20013681.0: 8,
#  20013805.0: 4,
#  20013833.0: 3,
#  20013887.0: 12,
#  20013839.0: 22,
#  20013908.0: 3,
#  20013945.0: 42,
#  20014014.0: 2,
#  20014005.0: 8,
#  20014114.0: 12,
#  20014311.0: 2,
#  20014349.0: 16,
#  20014367.0: 3,
#  20014557.0: 2,
#  20014583.0: 6,
#  20014671.0: 5,
#  20014753.0: 4,
#  20014900.0: 2,
#  20014909.0: 5,
#  20014884.0: 6,
#  20014963.0: 10,
#  20014980.0: 6,
#  20014952.0: 5,
#  20014999.0: 15,
#  20014990.0: 5,
#  20015009.0: 1,
#  20015012.0: 9,
#  20015204.0: 3,
#  20015213.0: 16,
#  20015241.0: 5,
#  20015407.0: 17,
#  20015290.0: 3,
#  20015496.0: 17,
#  20015409.0: 7,
#  20015513.0: 2,
#  20015603.0: 4,
#  20015601.0: 5,
#  20015661.0: 11,
#  20015725.0: 3,
#  20015663.0: 8,
#  20015766.0: 11,
#  20015883.0: 11,
#  20015872.0: 9,
#  20015946.0: 6,
#  20015927.0: 10,
#  20016063.0: 9,
#  20016181.0: 12,
#  20016160.0: 9,
#  20016249.0: 3,
#  20016270.0: 5,
#  20016283.0: 4,
#  20016290.0: 9,
#  20016465.0: 4,
#  20016521.0: 8,
#  20016550.0: 5,
#  20016582.0: 5,
#  20016661.0: 18,
#  20016714.0: 26,
#  20016768.0: 4,
#  20016748.0: 4,
#  20016879.0: 31,
#  20017150.0: 4,
#  20017191.0: 25,
#  20017263.0: 4,
#  20017294.0: 5,
#  20017169.0: 8,
#  20017299.0: 12,
#  20017364.0: 8,
#  20017382.0: 11,
#  20017368.0: 3,
#  20017390.0: 2,
#  20017456.0: 4,
#  20017530.0: 12,
#  20017560.0: 8,
#  20017589.0: 3,
#  20017593.0: 3,
#  20017622.0: 2,
#  20017597.0: 21,
#  20017658.0: 1,
#  20017633.0: 5,
#  20017731.0: 13,
#  20017720.0: 2,
#  20017834.0: 3,
#  20017858.0: 13,
#  20017885.0: 3,
#  20017886.0: 6,
#  20017949.0: 2,
#  20017926.0: 4,
#  20017989.0: 43,
#  20018024.0: 6,
#  20018154.0: 4,
#  20018171.0: 5,
#  20018249.0: 1,
#  20018250.0: 3,
#  20018294.0: 1,
#  20018199.0: 5,
#  20018297.0: 5,
#  20018388.0: 6,
#  20018314.0: 11,
#  20018555.0: 26,
#  20018638.0: 1,
#  20018606.0: 2,
#  20018698.0: 4,
#  20018764.0: 1,
#  20018767.0: 8,
#  20018993.0: 12,
#  20018774.0: 8,
#  20019012.0: 17,
#  20018837.0: 18,
#  20019084.0: 10,
#  20019120.0: 2,
#  20019063.0: 12,
#  20019162.0: 4,
#  20019304.0: 1,
#  20019398.0: 8,
#  20019404.0: 8,
#  20019429.0: 1,
#  20019503.0: 6,
#  20019690.0: 15,
#  20019700.0: 13,
#  20019850.0: 4,
#  20019873.0: 3,
#  20019875.0: 35,
#  20020077.0: 4,
#  20019940.0: 2,
#  20020095.0: 4,
#  20020103.0: 12,
#  20020286.0: 3,
#  20020317.0: 14,
#  20020402.0: 3,
#  20020471.0: 1,
#  20020549.0: 5,
#  20020537.0: 26,
#  20020517.0: 7,
#  20020565.0: 2,
#  20020676.0: 3,
#  20020575.0: 8,
#  20020693.0: 3,
#  20020728.0: 3,
#  20020821.0: 9,
#  20020959.0: 4,
#  20020875.0: 5,
#  20020934.0: 3,
#  20021031.0: 19,
#  20021144.0: 3,
#  20021088.0: 3,
#  20021171.0: 9,
#  20021268.0: 5,
#  20021455.0: 1,
#  20021394.0: 5,
#  20021217.0: 31,
#  20021715.0: 7,
#  20021752.0: 5,
#  20021858.0: 1,
#  20021730.0: 4,
#  20021747.0: 5,
#  20021879.0: 4,
#  20021899.0: 9,
#  20021922.0: 5,
#  20021991.0: 5,
#  20022078.0: 9,
#  20021932.0: 33,
#  20022097.0: 3,
#  20022095.0: 22,
#  20022233.0: 7,
#  20022223.0: 5,
#  20022243.0: 10,
#  20022252.0: 5,
#  20022345.0: 7,
#  20022256.0: 3,
#  20022403.0: 10,
#  20022423.0: 54,
#  20022471.0: 7,
#  20022465.0: 29,
#  20022560.0: 28,
#  20022678.0: 5,
#  20022686.0: 4,
#  20022675.0: 4,
#  20022720.0: 16,
#  20022725.0: 4,
#  20022888.0: 16,
#  20023045.0: 3,
#  20023047.0: 6,
#  20023059.0: 1,
#  20023063.0: 24,
#  20023073.0: 14,
#  20023065.0: 10,
#  20023216.0: 15,
#  20023191.0: 3,
#  20023218.0: 13,
#  20023225.0: 39,
#  20023280.0: 3,
#  20023249.0: 4,
#  20023283.0: 4,
#  20023470.0: 16,
#  20023531.0: 4,
#  20023544.0: 3,
#  20023642.0: 10,
#  20023656.0: 4,
#  20023678.0: 26,
#  20023715.0: 7,
#  20023731.0: 3,
#  20024056.0: 11,
#  20023734.0: 15,
#  20023787.0: 9,
#  20024137.0: 5,
#  20024068.0: 6,
#  20024286.0: 5,
#  20024353.0: 19,
#  20024163.0: 11,
#  20024404.0: 17,
#  20024373.0: 10,
#  20024537.0: 3,
#  20024565.0: 3,
#  20024592.0: 3,
#  20024645.0: 11,
#  20024463.0: 5,
#  20024717.0: 5,
#  20024839.0: 7,
#  20024769.0: 4,
#  20024981.0: 3,
#  20024986.0: 19,
#  20024999.0: 2,
#  20025037.0: 24,
#  20024997.0: 33,
#  20025071.0: 5,
#  20025072.0: 20,
#  20025252.0: 8,
#  20025245.0: 3,
#  20025201.0: 4,
#  20025280.0: 5,
#  20025420.0: 8,
#  20025296.0: 3,
#  20025356.0: 15,
#  20025501.0: 3,
#  20025548.0: 4,
#  20025569.0: 12,
#  20025595.0: 5,
#  20025975.0: 2,
#  20025581.0: 13,
#  20026025.0: 30,
#  20026051.0: 5,
#  20026038.0: 11,
#  20025997.0: 6,
#  20026118.0: 5,
#  20026217.0: 19,
#  20026286.0: 12,
#  20026493.0: 6,
#  20026530.0: 13,
#  20026517.0: 5,
#  20026371.0: 8,
#  20026585.0: 2,
#  20026711.0: 3,
#  20026802.0: 6,
#  20026975.0: 4,
#  20026981.0: 43,
#  20027047.0: 4,
#  20027082.0: 22,
#  20027093.0: 10,
#  20027099.0: 2,
#  20027117.0: 2,
#  20027120.0: 7,
#  20027176.0: 3,
#  20027198.0: 7,
#  20027267.0: 2,
#  20027203.0: 3,
#  20027293.0: 5,
#  20027296.0: 5,
#  20027300.0: 5,
#  20027403.0: 3,
#  20027368.0: 3,
#  20027438.0: 25,
#  20027439.0: 2,
#  20027569.0: 5,
#  20027590.0: 17,
#  20027704.0: 3,
#  20027677.0: 11,
#  20027751.0: 4,
#  20027733.0: 17,
#  20027810.0: 7,
#  20027822.0: 7,
#  20027865.0: 2,
#  20027867.0: 12,
#  20028032.0: 1,
#  20028086.0: 21,
#  20028113.0: 9,
#  20028125.0: 9,
#  20028142.0: 3,
#  20028182.0: 6,
#  20028263.0: 4,
#  20028434.0: 3,
#  20028236.0: 3,
#  20028540.0: 34,
#  20028545.0: 2,
#  20028591.0: 6,
#  20028551.0: 7,
#  20028593.0: 3,
#  20028611.0: 9,
#  20028638.0: 15,
#  20028640.0: 7,
#  20028694.0: 3,
#  20028712.0: 8,
#  20028723.0: 5,
#  20028802.0: 17,
#  20028732.0: 12,
#  20028957.0: 4,
#  20029054.0: 14,
#  20029059.0: 11,
#  20029188.0: 19,
#  20029194.0: 24,
#  20029140.0: 8,
#  20029327.0: 2,
#  20029195.0: 4,
#  20029334.0: 16,
#  20029431.0: 3,
#  20029427.0: 7,
#  20029433.0: 4,
#  20029435.0: 4,
#  20029476.0: 8,
#  20029504.0: 4,
#  20029508.0: 6,
#  20029579.0: 8,
#  20029740.0: 1,
#  20029639.0: 13,
#  20029891.0: 3,
#  20029921.0: 4,
#  20029966.0: 2,
#  20029993.0: 10,
#  20029969.0: 2,
#  20030275.0: 7,
#  20030294.0: 16,
#  20030338.0: 11,
#  20030374.0: 6,
#  20030325.0: 12,
#  20030445.0: 3,
#  20030549.0: 2,
#  20030550.0: 9,
#  20030680.0: 16,
#  20030694.0: 3,
#  20030660.0: 63,
#  20030823.0: 9,
#  20030722.0: 6,
#  20030909.0: 6,
#  20030937.0: 5,
#  20030948.0: 4,
#  20031018.0: 2,
#  20031042.0: 2,
#  20031090.0: 5,
#  20031176.0: 2,
#  20031226.0: 23,
#  20031400.0: 9,
#  20031229.0: 2,
#  20031260.0: 3,
#  20031514.0: 2,
#  20031515.0: 4,
#  20031590.0: 7,
#  20031762.0: 6,
#  20031775.0: 7,
#  20031861.0: 8,
#  20031810.0: 4,
#  20031593.0: 17,
#  20031795.0: 11,
#  20031947.0: 2,
#  20032048.0: 21,
#  20032092.0: 6,
#  20031917.0: 4,
#  20032235.0: 12,
#  20032274.0: 2,
#  20032123.0: 12,
#  20032433.0: 5,
#  20032552.0: 9,
#  20032529.0: 1,
#  20032641.0: 1,
#  20032645.0: 14,
#  20032731.0: 12,
#  20032762.0: 15,
#  20032691.0: 16,
#  20032769.0: 15,
#  20032792.0: 19,
#  20032786.0: 8,
#  20032822.0: 3,
#  20032965.0: 5,
#  20032996.0: 9,
#  20033103.0: 3,
#  20033189.0: 13,
#  20033298.0: 7,
#  20033307.0: 4,
#  20033338.0: 10,
#  20033619.0: 3,
#  20033352.0: 2,
#  20033370.0: 3,
#  20033365.0: 5,
#  20033684.0: 3,
#  20033897.0: 7,
#  20033886.0: 3,
#  20033946.0: 5,
#  20033978.0: 1,
#  20034306.0: 6,
#  20034178.0: 5,
#  20034302.0: 7,
#  20034340.0: 35,
#  20034582.0: 7,
#  20034501.0: 12,
#  20034658.0: 16,
#  20034752.0: 13,
#  20034685.0: 23,
#  20034781.0: 12,
#  20034783.0: 3,
#  20034789.0: 4,
#  20035051.0: 10,
#  20034788.0: 68,
#  20034818.0: 12,
#  20035274.0: 4,
#  20035459.0: 5,
#  20035156.0: 6,
#  20035405.0: 19,
#  20035499.0: 2,
#  20035575.0: 3,
#  20035535.0: 9,
#  20035597.0: 4,
#  20035617.0: 5,
#  20035723.0: 4,
#  20035797.0: 7,
#  20035761.0: 3,
#  20035624.0: 5,
#  20035806.0: 3,
#  20035840.0: 10,
#  20036006.0: 6,
#  20035911.0: 1,
#  20035897.0: 3,
#  20036074.0: 2,
#  20036035.0: 32,
#  20036159.0: 3,
#  20036409.0: 12,
#  20036311.0: 8,
#  20036437.0: 4,
#  20036441.0: 16,
#  20036599.0: 4,
#  20036759.0: 6,
#  20036714.0: 44,
#  20036798.0: 5,
#  20036761.0: 5,
#  20036938.0: 31,
#  20036902.0: 8,
#  20036996.0: 9,
#  20037022.0: 2,
#  20037053.0: 10,
#  20037076.0: 5,
#  20037104.0: 7,
#  20037149.0: 6,
#  20037205.0: 29,
#  20037269.0: 7,
#  20037319.0: 9,
#  20037266.0: 1,
#  20037261.0: 5,
#  20037348.0: 7,
#  20037406.0: 26,
#  20037428.0: 16,
#  20037579.0: 3,
#  20037549.0: 13,
#  20037621.0: 2,
#  20037663.0: 5,
#  20037852.0: 2,
#  20037934.0: 7,
#  20038120.0: 4,
#  20038127.0: 3,
#  20038168.0: 3,
#  20038174.0: 2,
#  20038326.0: 10,
#  20038327.0: 13,
#  20038354.0: 7,
#  20038451.0: 5,
#  20038277.0: 3,
#  20038596.0: 7,
#  20038621.0: 4,
#  20038532.0: 3,
#  20038633.0: 9,
#  20038609.0: 4,
#  20038733.0: 3,
#  20038784.0: 9,
#  20038638.0: 77,
#  20038948.0: 2,
#  20038985.0: 5,
#  20039129.0: 10,
#  20039307.0: 8,
#  20039051.0: 3,
#  20039322.0: 3,
#  20039308.0: 7,
#  20039414.0: 11,
#  20039535.0: 7,
#  20039586.0: 26,
#  20039750.0: 11,
#  20039701.0: 5,
#  20039765.0: 11,
#  20039781.0: 3,
#  20039902.0: 1,
#  20040037.0: 3,
#  20040078.0: 2,
#  20040163.0: 2,
#  20040177.0: 9,
#  20040161.0: 2,
#  20040209.0: 5,
#  20040362.0: 1,
#  20040434.0: 15,
#  20040313.0: 12,
#  20040488.0: 6,
#  20040734.0: 7,
#  20040953.0: 3,
#  20041137.0: 2,
#  20040961.0: 3,
#  20041056.0: 7,
#  20041142.0: 14,
#  20041128.0: 4,
#  20041191.0: 8,
#  20041155.0: 5,
#  20041184.0: 7,
#  20041154.0: 13,
#  20041256.0: 3,
#  20041302.0: 2,
#  20041342.0: 19,
#  20041465.0: 3,
#  20041367.0: 5,
#  20041429.0: 31,
#  20041385.0: 2,
#  20041510.0: 23,
#  20041504.0: 9,
#  20041577.0: 4,
#  20041599.0: 7,
#  20041555.0: 2,
#  20041764.0: 3,
#  20041838.0: 2,
#  20041808.0: 27,
#  20041872.0: 12,
#  20041858.0: 1,
#  20041934.0: 17,
#  20041946.0: 1,
#  20042079.0: 18,
#  20042049.0: 1,
#  20042111.0: 4,
#  20042052.0: 5,
#  20042170.0: 4,
#  20042194.0: 3,
#  20042221.0: 5,
#  20042228.0: 49,
#  20042244.0: 1,
#  20042287.0: 4,
#  20042293.0: 19,
#  20042405.0: 42,
#  20042475.0: 12,
#  20042555.0: 4,
#  20042646.0: 3,
#  20042733.0: 4,
#  20042822.0: 3,
#  20042920.0: 4,
#  20042625.0: 3,
#  20042975.0: 10,
#  20042939.0: 4,
#  20042977.0: 2,
#  20043076.0: 20,
#  20042992.0: 7,
#  20043207.0: 2,
#  20043184.0: 25,
#  20043241.0: 11,
#  20043146.0: 3,
#  20043280.0: 9,
#  20043252.0: 4,
#  20043361.0: 4,
#  20043360.0: 9,
#  20043299.0: 14,
#  20043420.0: 8,
#  20043611.0: 4,
#  20043805.0: 2,
#  20043705.0: 5,
#  20043675.0: 14,
#  20043814.0: 16,
#  20043887.0: 4,
#  20043816.0: 19,
#  20043933.0: 3,
#  20043906.0: 7,
#  20044084.0: 7,
#  20044161.0: 1,
#  20044149.0: 44,
#  20044326.0: 12,
#  20044402.0: 2,
#  20044413.0: 5,
#  20044222.0: 1,
#  20044443.0: 4,
#  20044580.0: 6,
#  20044592.0: 4,
#  20044587.0: 24,
#  20044602.0: 11,
#  20044738.0: 38,
#  20044804.0: 2,
#  20044790.0: 11,
#  20044809.0: 6,
#  20044898.0: 5,
#  20044900.0: 39,
#  20044923.0: 4,
#  20044939.0: 11,
#  20045085.0: 4,
#  20045152.0: 28,
#  20045198.0: 3,
#  20045188.0: 3,
#  20045301.0: 13,
#  20045226.0: 9,
#  20045327.0: 4,
#  20045369.0: 2,
#  20045419.0: 4,
#  20045711.0: 2,
#  20045455.0: 18,
#  20045490.0: 8,
#  20045804.0: 9,
#  20045824.0: 2,
#  20045892.0: 4,
#  20045896.0: 4,
#  20045907.0: 3,
#  20045911.0: 1,
#  20046020.0: 7,
#  20046028.0: 7,
#  20046114.0: 9,
#  20046098.0: 4,
#  20046216.0: 4,
#  20046146.0: 5,
#  20046257.0: 21,
#  20046413.0: 3,
#  20046470.0: 6,
#  20046372.0: 35,
#  20046602.0: 3,
#  20046734.0: 13,
#  20046699.0: 20,
#  20046807.0: 3,
#  20046629.0: 18,
#  20046810.0: 5,
#  20046876.0: 3,
#  20046933.0: 1,
#  20046885.0: 11,
#  20046954.0: 2,
#  20047012.0: 9,
#  20047014.0: 11,
#  20047046.0: 7,
#  20047125.0: 8,
#  20047355.0: 9,
#  20047228.0: 12,
#  20047375.0: 17,
#  20047499.0: 7,
#  20047513.0: 6,
#  20047558.0: 5,
#  20047580.0: 4,
#  20047686.0: 13,
#  20047705.0: 14,
#  20047616.0: 25,
#  20047663.0: 2,
#  20047936.0: 5,
#  20047783.0: 1,
#  20047797.0: 20,
#  20047709.0: 5,
#  20047947.0: 2,
#  20048013.0: 4,
#  20048168.0: 8,
#  20048217.0: 11,
#  20048109.0: 4,
#  20048237.0: 2,
#  20048223.0: 7,
#  20048542.0: 3,
#  20048247.0: 14,
#  20048682.0: 12,
#  20048798.0: 23,
#  20048801.0: 12,
#  20048847.0: 4,
#  20048854.0: 26,
#  20049020.0: 3,
#  20048930.0: 2,
#  20049178.0: 5,
#  20049183.0: 3,
#  20049075.0: 14,
#  20049221.0: 7,
#  20049227.0: 4,
#  20049406.0: 3,
#  20049265.0: 5,
#  20049447.0: 6,
#  20049511.0: 4,
#  20049586.0: 2,
#  20049739.0: 1,
#  20049541.0: 9,
#  20049907.0: 7,
#  20049742.0: 11,
#  20050104.0: 2,
#  20050106.0: 4,
#  20050172.0: 1,
#  20050136.0: 7,
#  20050333.0: 16,
#  20050572.0: 4,
#  20050530.0: 15,
#  20050609.0: 5,
#  20050633.0: 7,
#  20050595.0: 33,
#  20050685.0: 24,
#  20050816.0: 5,
#  20050858.0: 7,
#  20050878.0: 7,
#  20050922.0: 9,
#  20050936.0: 14,
#  20051022.0: 11,
#  20051246.0: 4,
#  20051249.0: 1,
#  20051296.0: 4,
#  20051301.0: 8,
#  20051363.0: 3,
#  20051401.0: 5,
#  20051451.0: 3,
#  20051645.0: 1,
#  20051521.0: 5,
#  20051479.0: 8,
#  20051652.0: 16,
#  20051745.0: 6,
#  20051666.0: 2,
#  20051790.0: 18,
#  20051827.0: 5,
#  20052021.0: 4,
#  20051972.0: 20,
#  20052117.0: 2,
#  20052112.0: 32,
#  20052142.0: 11,
#  20052318.0: 3,
#  20052309.0: 1,
#  20052356.0: 4,
#  20052440.0: 4,
#  20052390.0: 32,
#  20052398.0: 6,
#  20052451.0: 23,
#  20052479.0: 23,
#  20052594.0: 15,
#  20052610.0: 14,
#  20052539.0: 7,
#  20052724.0: 2,
#  20052651.0: 19,
#  20052674.0: 2,
#  20052780.0: 3,
#  20052795.0: 17,
#  20052891.0: 3,
#  20052942.0: 4,
#  20052859.0: 24,
#  20052997.0: 1,
#  20053273.0: 4,
#  20052976.0: 6,
#  20052963.0: 5,
#  20053327.0: 12,
#  20053484.0: 7,
#  20053563.0: 10,
#  20053447.0: 4,
#  20053590.0: 18,
#  ...}

# %%
hadms_list = [int(key) for key, _ in hadm_lengths.items()]

# %%
True if hadm_id in hadms_list else False
# Out:
# True
